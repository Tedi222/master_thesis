# %%
# %run ./dwi_to_conmat.py
# Out:
# 230417-12:35:56,179 nipype.utils DEBUG:
# 	 Running a newer version (1.8.5) of nipy/nipype than available (1.8.4)
# 230417-12:35:56,460 nipype.workflow DEBUG:
# 	 (tedi_TractoTest_newEnv.fileselector, tedi_TractoTest_newEnv.merge_bvec_bval): No edge data
# 230417-12:35:56,462 nipype.workflow DEBUG:
# 	 (tedi_TractoTest_newEnv.fileselector, tedi_TractoTest_newEnv.merge_bvec_bval): new edge data: {'connect': [('bvecs', 'file1'), ('bvals', 'file2')]}
# 230417-12:35:56,463 nipype.workflow DEBUG:
# 	 (tedi_TractoTest_newEnv.fileselector, tedi_TractoTest_newEnv.nii2mif): No edge data
# 230417-12:35:56,464 nipype.workflow DEBUG:
# 	 (tedi_TractoTest_newEnv.fileselector, tedi_TractoTest_newEnv.nii2mif): new edge data: {'connect': [('dwi', 'in_file')]}
# 230417-12:35:56,465 nipype.workflow DEBUG:
# 	 (tedi_TractoTest_newEnv.merge_bvec_bval, tedi_TractoTest_newEnv.nii2mif): No edge data
# 230417-12:35:56,466 nipype.workflow DEBUG:
# ...

# %%
/usr/bin/python /home/teodorps/diffusion-pipeline/pipelines/dwi_to_conmat.py

# %%
# %run -i 'dwi_to_conmat.py'
